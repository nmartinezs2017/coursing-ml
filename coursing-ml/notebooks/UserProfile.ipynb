# %%
# %reload_kedro
# Out:
# c:\users\enrmeao\pycharmprojects\coursing\venv\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 2021-06-20 12:44:37,639 - root - INFO - ** Kedro project coursing-ml
# 2021-06-20 12:44:37,641 - root - INFO - Defined global variable `context` and `catalog`

# %%
df = catalog.load("cleaned_udemy")
df.head()
# Out:
# 2021-06-20 12:44:56,004 - kedro.io.data_catalog - INFO - Loading data from `cleaned_udemy` (CSVDataSet)...
#     category    cost                                        description  \
# 0  Marketing  109.99  Full WordPress With All premium Theme And Plug...
# 1  Marketing   49.99  Implement chatbot on your website and start co...
# 2  Marketing   24.99  BRAND NEW ! 'Transform' your Social media Prof...
# 3  Marketing  109.99  Grow an Email List of Warm and Qualified Leads...
# 4  Marketing   49.99  Identify your target market create actionable ...
#
#                                   description_extend  free       instructor  \
# 0  Learn Full Digital Marketing Training Start To...     0  Harvinder Kumar
# 1  In this course I will be covering how you can ...     0          Sayed N
# 2  You are provided with every template tool and ...     0       blake nuba
# 3  Email Marketing is still surprisingly underrat...     0     Ilya Lobanov
# ...

# %%
df.language.unique()
# Out:
# c:\users\enrmeao\pycharmprojects\coursing\venv\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array(['English', 'German', 'Portuguese', 'Romanian', 'Arabic', 'Italian',
#        'Hungarian', 'French', 'Persian', 'Turkish', 'Spanish',
#        'Indonesian', 'Simplified Chinese', 'Japanese', 'Polish', 'Hindi',
#        'Russian', 'Vietnamese', 'Thai', 'Dutch', 'Kazakh',
#        'Traditional Chinese', 'Hebrew', 'Urdu', 'Bengali', 'Tamil',
#        'Telugu', 'Norwegian', 'Korean', 'Czech', 'Greek', 'Burmese',
#        'Serbian', 'Finnish', 'Filipino', 'Pashto', 'Malayalam',
#        'Croatian', 'Kannada', 'Danish', 'Marathi', 'Azeri', 'Georgian',
# ...

# %%
df.describe()
# Out:
#                 cost           free    n_students         rating  \
# count  117766.000000  117766.000000  1.177660e+05  117766.000000
# mean       54.039027       0.104164  3.288358e+03       3.732931
# std        40.180803       0.305475  1.663707e+04       1.447857
# min         0.000000       0.000000  0.000000e+00       0.000000
# 25%        19.990000       0.000000  2.800000e+01       3.700000
# 50%        49.990000       0.000000  2.430000e+02       4.200000
# 75%        94.990000       0.000000  1.742000e+03       4.600000
# max       199.990000       1.000000  1.582257e+06       5.000000
#
#                hours
# count  117766.000000
# mean        4.228630
# std         7.472876
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         4.000000
# max       254.000000

# %%
df_profile = df.sort_values("n_students", ascending=False)[0:100]
df_profile
# Out:
#                     category    cost  \
# 86743            Development    0.00
# 82325            Development  109.99
# 36685   Teaching & Academics    0.00
# 36634   Teaching & Academics    0.00
# 36680       Online Education    0.00
# ...                      ...     ...
# 4478             Development    0.00
# 92574          IT & Software  109.99
# 98826            Development   19.99
# 105401   Photography & Video   49.99
# 67736    Office Productivity  139.99
#
#                                               description  \
# 86743   Learn to program using the Java programming la...
# 82325   Learn Python like a Professional  Start from t...
# 36685   Equipment tips and setup best practices for hi...
# 36634   Learn easy edits to take your course from good...
# 36680     Learn to recognize high audio and video quality
# ...                                                   ...
# 4478    Aprenda desde o controle de versão ferramentas...
# ...

# %%
df_profile.describe()
# Out:
# c:\users\enrmeao\pycharmprojects\coursing\venv\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#              cost        free    n_students      rating       hours
# count  100.000000  100.000000  1.000000e+02  100.000000  100.000000
# mean    57.394100    0.410000  3.830778e+05    4.500000   18.050667
# std     54.594643    0.494311  2.502041e+05    0.158274   19.056294
# min      0.000000    0.000000  2.070120e+05    4.000000    0.533333
# 25%      0.000000    0.000000  2.286695e+05    4.400000    5.000000
# 50%     49.990000    0.000000  2.829160e+05    4.500000   12.000000
# 75%    109.990000    1.000000  4.213238e+05    4.600000   24.000000
# ...
